# %% [markdown]
# ### Question
# Plot a bar chart of the top 10 countries with the highest number of Netflix titles

# %%
df['country'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# ### Question
# what are the different types of ratings

# %%
import pandas as pd
df = pd.read_csv(r"O:\AI_ML\Github\InsightGen-AI\data\uploads\uploaded_csv.csv")

# %%
print(df['rating'].apply(lambda x: '.'.join(filter(str.isalpha, str(x))) if isinstance(x, str) else None)).value_counts().index
# Out:
# 0           P.G
# 1       T.V.M.A
# 2       T.V.M.A
# 3       T.V.M.A
# 4       T.V.M.A
#          ...
# 8802          R
# 8803      T.V.Y
# 8804          R
# 8805        P.G
# 8806        T.V
# Name: rating, Length: 8807, dtype: object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(df['rating'].apply(lambda x: '.'.join(filter(str.isalpha, str(x))) if isinstance(x, str) else None)).value_counts().index
#
# AttributeError: 'NoneType' object has no attribute 'value_counts'
